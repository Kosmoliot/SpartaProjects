# %%
import pandas as pd

# %% [markdown]
# # Reading iris.csv file

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Grouping by species & finding descriptive stats for the groups

# %%
df.groupby('species').describe()
# Out:
#            sepal_length
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8  \
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244  \
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %%
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# # Add a rank column to the iris DataFrame, ranking the petal length in an ascending order

# %%
new_rank_df = df.sort_values(by=['petal_length']).reset_index(drop=True)
new_rank_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             4.6          3.6           1.0          0.2     setosa
# 1             4.3          3.0           1.1          0.1     setosa
# 2             5.8          4.0           1.2          0.2     setosa
# 3             5.0          3.2           1.2          0.2     setosa
# 4             5.5          3.5           1.3          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.9          3.8           6.4          2.0  virginica
# 146           7.6          3.0           6.6          2.1  virginica
# 147           7.7          3.8           6.7          2.2  virginica
# 148           7.7          2.8           6.7          2.0  virginica
# 149           7.7          2.6           6.9          2.3  virginica
#
# [150 rows x 5 columns]

# %%
df['rank'] = df['petal_length'].rank(ascending=True)
df.set_index('rank', inplace=True)
df.sort_index()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width    species
# rank
# 1.0             4.6          3.6           1.0          0.2     setosa
# 2.0             4.3          3.0           1.1          0.1     setosa
# 3.5             5.8          4.0           1.2          0.2     setosa
# 3.5             5.0          3.2           1.2          0.2     setosa
# 8.0             5.5          3.5           1.3          0.2     setosa
# ...             ...          ...           ...          ...        ...
# 146.0           7.9          3.8           6.4          2.0  virginica
# 147.0           7.6          3.0           6.6          2.1  virginica
# 148.5           7.7          3.8           6.7          2.2  virginica
# 148.5           7.7          2.8           6.7          2.0  virginica
# 150.0           7.7          2.6           6.9          2.3  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Find the mean of each column for each species

# %%
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# # Create a new DataFrame for each of the species

# %%
setosa_df = df[df['species'] == 'setosa']
setosa_df.reset_index(drop=True)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
versicolor_df = df[df['species'] == 'versicolor']
versicolor_df.reset_index(drop=True)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            7.0          3.2           4.7          1.4  versicolor
# 1            6.4          3.2           4.5          1.5  versicolor
# 2            6.9          3.1           4.9          1.5  versicolor
# 3            5.5          2.3           4.0          1.3  versicolor
# 4            6.5          2.8           4.6          1.5  versicolor
# 5            5.7          2.8           4.5          1.3  versicolor
# 6            6.3          3.3           4.7          1.6  versicolor
# 7            4.9          2.4           3.3          1.0  versicolor
# 8            6.6          2.9           4.6          1.3  versicolor
# 9            5.2          2.7           3.9          1.4  versicolor
# 10           5.0          2.0           3.5          1.0  versicolor
# 11           5.9          3.0           4.2          1.5  versicolor
# 12           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
virginica_df = df[df['species'] == 'virginica']
virginica_df.reset_index(drop=True)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            6.3          3.3           6.0          2.5  virginica
# 1            5.8          2.7           5.1          1.9  virginica
# 2            7.1          3.0           5.9          2.1  virginica
# 3            6.3          2.9           5.6          1.8  virginica
# 4            6.5          3.0           5.8          2.2  virginica
# 5            7.6          3.0           6.6          2.1  virginica
# 6            4.9          2.5           4.5          1.7  virginica
# 7            7.3          2.9           6.3          1.8  virginica
# 8            6.7          2.5           5.8          1.8  virginica
# 9            7.2          3.6           6.1          2.5  virginica
# 10           6.5          3.2           5.1          2.0  virginica
# 11           6.4          2.7           5.3          1.9  virginica
# 12           6.8          3.0           5.5          2.1  virginica
# ...

# %% [markdown]
# # Sepal DataFrame

# %%
sepla_df = df[['sepal_length', 'sepal_width', 'species']].sort_index()
sepla_df
# Out:
#        sepal_length  sepal_width    species
# rank
# 1.0             4.6          3.6     setosa
# 2.0             4.3          3.0     setosa
# 3.5             5.8          4.0     setosa
# 3.5             5.0          3.2     setosa
# 8.0             5.5          3.5     setosa
# ...             ...          ...        ...
# 146.0           7.9          3.8  virginica
# 147.0           7.6          3.0  virginica
# 148.5           7.7          3.8  virginica
# 148.5           7.7          2.8  virginica
# 150.0           7.7          2.6  virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# # Petal DataFrame

# %%
sepla_df = df[['petal_length', 'petal_width', 'species']].sort_index()
sepla_df
# Out:
#        petal_length  petal_width    species
# rank
# 1.0             1.0          0.2     setosa
# 2.0             1.1          0.1     setosa
# 3.5             1.2          0.2     setosa
# 3.5             1.2          0.2     setosa
# 8.0             1.3          0.2     setosa
# ...             ...          ...        ...
# 146.0           6.4          2.0  virginica
# 147.0           6.6          2.1  virginica
# 148.5           6.7          2.2  virginica
# 148.5           6.7          2.0  virginica
# 150.0           6.9          2.3  virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# # Concatenation

# %%
# Lab Answer - Creating a new DataFrame for each of the species (Needed for concatenation)
vers = df[df['species'] == 'versicolor']
setosa = df[df['species'] == 'setosa']
virg = df[df['species'] == 'virginica']
vers
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# rank
# 93.0            7.0          3.2           4.7          1.4  versicolor
# 83.5            6.4          3.2           4.5          1.5  versicolor
# 102.0           6.9          3.1           4.9          1.5  versicolor
# 64.0            5.5          2.3           4.0          1.3  versicolor
# 89.0            6.5          2.8           4.6          1.5  versicolor
# 83.5            5.7          2.8           4.5          1.3  versicolor
# 93.0            6.3          3.3           4.7          1.6  versicolor
# 52.5            4.9          2.4           3.3          1.0  versicolor
# 89.0            6.6          2.9           4.6          1.3  versicolor
# 60.0            5.2          2.7           3.9          1.4  versicolor
# 54.5            5.0          2.0           3.5          1.0  versicolor
# 71.5            5.9          3.0           4.2          1.5  versicolor
# ...

# %%
pd.concat([vers,setosa], axis=0)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# rank
# 93.0            7.0          3.2           4.7          1.4  versicolor
# 83.5            6.4          3.2           4.5          1.5  versicolor
# 102.0           6.9          3.1           4.9          1.5  versicolor
# 64.0            5.5          2.3           4.0          1.3  versicolor
# 89.0            6.5          2.8           4.6          1.5  versicolor
# ...             ...          ...           ...          ...         ...
# 17.5            4.8          3.0           1.4          0.3      setosa
# 41.0            5.1          3.8           1.6          0.2      setosa
# 17.5            4.6          3.2           1.4          0.2      setosa
# 30.5            5.3          3.7           1.5          0.2      setosa
# 17.5            5.0          3.3           1.4          0.2      setosa
#
# [100 rows x 5 columns]

# %%
# Lab Answer - Creating two DataFrames for Sepal and Petal information (Needed for merging)
sepal_info = pd.DataFrame({'sepal_length':df['sepal_length'],'sepal_width':df['sepal_width'],'species':df['species']})
petal_info = pd.DataFrame({'petal_length':df['petal_length'],'petal_width':df['petal_width'],'species':df['species']})
sepal_info
# Out:
#        sepal_length  sepal_width    species
# rank
# 17.5            5.1          3.5     setosa
# 17.5            4.9          3.0     setosa
# 8.0             4.7          3.2     setosa
# 30.5            4.6          3.1     setosa
# 17.5            5.0          3.6     setosa
# ...             ...          ...        ...
# 117.5           6.7          3.0  virginica
# 106.5           6.3          2.5  virginica
# 117.5           6.5          3.0  virginica
# 121.5           6.2          3.4  virginica
# 112.5           5.9          3.0  virginica
#
# [150 rows x 3 columns]

# %%
pd.merge(sepal_info, petal_info, how='inner', right_index=True, left_index=True)
# Out:
#        sepal_length  sepal_width  species_x  petal_length  petal_width
# rank
# 1.0             4.6          3.6     setosa           1.0          0.2  \
# 2.0             4.3          3.0     setosa           1.1          0.1
# 3.5             5.8          4.0     setosa           1.2          0.2
# 3.5             5.8          4.0     setosa           1.2          0.2
# 3.5             5.0          3.2     setosa           1.2          0.2
# ...             ...          ...        ...           ...          ...
# 148.5           7.7          3.8  virginica           6.7          2.2
# 148.5           7.7          3.8  virginica           6.7          2.0
# 148.5           7.7          2.8  virginica           6.7          2.2
# 148.5           7.7          2.8  virginica           6.7          2.0
# 150.0           7.7          2.6  virginica           6.9          2.3
#
#        species_y
# rank
# 1.0       setosa
# 2.0       setosa
# 3.5       setosa
# 3.5       setosa
# ...

# %%
df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})
df1
# Out:
#      a  b
# 0  foo  1
# 1  bar  2

# %%
df2
# Out:
#      a  c
# 0  foo  3
# 1  baz  4

# %%
df1.merge(df2, how='inner', on='a')
# Out:
#      a  b  c
# 0  foo  1  3

# %%
df1.merge(df2, how='left', on='a')
# Out:
#      a  b    c
# 0  foo  1  3.0
# 1  bar  2  NaN
